# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import mxnet as mx 
from symbol import get_resnet_model
from symbol import YOLO_loss
from data_ulti import get_iterator

# %%
def decodeBox(yolobox, size, dscale):
    i, j, cx, cy, w, h = yolobox
    cxt = j*dscale + cx*dscale
    cyt = i*dscale + cy*dscale
    wt = w*size
    ht = h*size
    return [cxt, cyt, wt, ht]

def bboxdraw(img, label, dscale=32):
    assert label.shape == (7,7,5)
    size = img.shape[1]
    ilist, jlist = np.where(label[:,:,0]>0.2)
    
    # Create figure and axes
    fig,ax = plt.subplots(1)
    ax.imshow(np.uint8(img))
    for i,j in zip(ilist, jlist): 
        cx,cy,w,h = label[i,j,1:]
        cxt, cyt, wt ,ht = decodeBox([i, j, cx,cy,w,h], size, dscale)
        # Create a Rectangle patch
        rect = patches.Rectangle((cxt-wt/2,cyt-ht/2), wt,ht,linewidth=1,edgecolor='r',facecolor='none')

        # Add the patch to the Axes
        ax.add_patch(rect)
    
        plt.plot(int(cxt), int(cyt), '*')
    plt.show()

# %%
data = mx.io.ImageRecordIter(path_imgrec='DATA_rec/cat_small.rec',
                             data_shape=(3,224,224),
                             label_width=7*7*5, 
                             batch_size=1,)

# %%
# get sym 
sym, args_params, aux_params = mx.model.load_checkpoint('models/cat_detect_full_scale', 600)
logit = sym.get_internals()['logit_output']
mod = mx.mod.Module(symbol=logit, context=mx.gpu(0))
mod.bind(data.provide_data)
mod.init_params(allow_missing=False, arg_params=args_params, aux_params=aux_params, 
                initializer=mx.init.Xavier(magnitude=2,rnd_type='gaussian',factor_type='in'))
out = mod.predict(eval_data=data, num_batch=10)
# Out:
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# <ipython-input-4-60583a3c2e37> in <module>()
#       1 # get sym
# ----> 2 sym, args_params, aux_params = mx.model.load_checkpoint('models/cat_detect', 600)
#       3 logit = sym.get_internals()['logit_output']
#       4 mod = mx.mod.Module(symbol=logit, context=mx.gpu(0))
#       5 mod.bind(data.provide_data)
#
# /home/chuck/DLenv/MXNet/local/lib/python2.7/site-packages/mxnet/model.pyc in load_checkpoint(prefix, epoch)
#     371     - Parameters will be loaded from ``prefix-epoch.params``.
#     372     """
# --> 373     symbol = sym.load('%s-symbol.json' % prefix)
#     374     save_dict = nd.load('%s-%04d.params' % (prefix, epoch))
#     375     arg_params = {}
#
# /home/chuck/DLenv/MXNet/local/lib/python2.7/site-packages/mxnet/symbol.pyc in load(fname)
#    1624         raise TypeError('fname need to be string')
#    1625     handle = SymbolHandle()
# -> 1626     check_call(_LIB.MXSymbolCreateFromFile(c_str(fname), ctypes.byref(handle)))
#    1627     return Symbol(handle)
#    1628
#
# /home/chuck/DLenv/MXNet/local/lib/python2.7/site-packages/mxnet/base.pyc in check_call(ret)
#      82     """
#      83     if ret != 0:
# ---> 84         raise MXNetError(py_str(_LIB.MXGetLastError()))
#      85
#      86 if sys.version_info[0] < 3:
#
# MXNetError: [23:47:33] src/io/local_filesys.cc:154: Check failed: allow_null  LocalFileSystem: fail to open "models/cat_detect-symbol.json"
#
# Stack trace returned 10 entries:
# [bt] (0) /home/chuck/DLenv/MXNet/local/lib/python2.7/site-packages/mxnet/libmxnet.so(+0x115b9d9) [0x7fed8a1c29d9]
# [bt] (1) /home/chuck/DLenv/MXNet/local/lib/python2.7/site-packages/mxnet/libmxnet.so(+0x1153e3a) [0x7fed8a1bae3a]
# [bt] (2) /home/chuck/DLenv/MXNet/local/lib/python2.7/site-packages/mxnet/libmxnet.so(MXSymbolCreateFromFile+0x4e) [0x7fed89d6dbae]
# [bt] (3) /usr/lib/x86_64-linux-gnu/libffi.so.6(ffi_call_unix64+0x4c) [0x7fedc41c8e40]
# [bt] (4) /usr/lib/x86_64-linux-gnu/libffi.so.6(ffi_call+0x2eb) [0x7fedc41c88ab]
# [bt] (5) /home/chuck/DLenv/MXNet/lib/python2.7/lib-dynload/_ctypes.x86_64-linux-gnu.so(_ctypes_callproc+0x48f) [0x7fedc43d83df]
# [bt] (6) /home/chuck/DLenv/MXNet/lib/python2.7/lib-dynload/_ctypes.x86_64-linux-gnu.so(+0x11d82) [0x7fedc43dcd82]
# [bt] (7) /home/chuck/DLenv/MXNet/bin/python(PyObject_Call+0x43) [0x4b0cb3]
# [bt] (8) /home/chuck/DLenv/MXNet/bin/python(PyEval_EvalFrameEx+0x5faf) [0x4c9faf]
# [bt] (9) /home/chuck/DLenv/MXNet/bin/python(PyEval_EvalCodeEx+0x255) [0x4c2765]

# %%
data.reset()
batch = data.next()
img = batch.data[0].asnumpy()[0].transpose((1,2,0))
label = batch.label[0].asnumpy().reshape((7,7,5))
pred = (out.asnumpy()[0]+1)/2
print pred.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f6ce61d13a55> in <module>()
#       3 img = batch.data[0].asnumpy()[0].transpose((1,2,0))
#       4 label = batch.label[0].asnumpy().reshape((7,7,5))
# ----> 5 pred = (out.asnumpy()[0]+1)/2
#       6 print pred.shape
#
# NameError: name 'out' is not defined

# %%
print "Prediction"
bboxdraw(img, pred)
# Out:
# Prediction

# %%
print "Ground Truth"
bboxdraw(img, label)
# Out:
# Ground Truth
